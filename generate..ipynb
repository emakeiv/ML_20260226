# %%
from drawdata import ScatterWidget

widget = ScatterWidget()
widget
# Out:
# Running cells with 'ml-20260226 (Python 3.12.1)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/workspaces/ML_20260226/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
